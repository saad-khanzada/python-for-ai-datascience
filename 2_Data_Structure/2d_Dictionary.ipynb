# %% [markdown]
# # Dictionaries in Python
#
# Dictionaries are a powerful built-in data structure in Python that store data as **key–value pairs**. They allow fast lookups and are widely used in AI, Data Science, and everyday Python programming.

# %% [markdown]
# ### 📑 Table of Contents
# 1. [Introduction to Dictionaries](#intro)
# 2. [Creating Dictionaries](#creat)
# 3. [Accessing Data](#access)
# 4. [Modifying ](#update)
# 5. [Lopping through a Dictionaries](#iterate)
# 6. [Dictionary Method](#examples)
# 7. [ Nested Dictionaries](#Nested_Dictionaries)
# 8. [Summary & Key Takeaways](#summary)
# ---

# %% [markdown]
# ## 🚀  **Python Dictionaries: A Beginner's Guide to Key-Value Data Storage** 🧩

# %% [markdown]
# <hr>

# %% [markdown]
# ###  Introduction to Dictionaries

# %% [markdown]
# #### What is a Dictionary?

# %% [markdown]
# A dictionary in Python is a collection of key-value pairs. It allows you to store and retrieve data efficiently.

# %% [markdown]
# ##### Creating a Dictionary

# %%
# Creating a dictionary of student information
student = {
    "name": "saad",
    "age": 20,
    "grade": "A",
    "city": "Islamabad"
}
print(student)

# %% [markdown]
# #### 📌 Key Points:
#
# - **Keys** must be **unique** and **immutable** (e.g., strings, numbers, tuples).
# - **Values** can be of **any data type**.
# - **Dictionaries are unordered** in Python versions **before 3.7** and **ordered in Python 3.7+**.

# %% [markdown]
# **✅ Practice Exercise:**

# %%
# Create a dictionary of your favorite book with details like title, author, and publication year.

# %% [markdown]
# <hr>

# %% [markdown]
# ####  Accessing Dictionary Values

# %% [markdown]
# We can access dictionary values using their  <code> keys <code\>

# %%
# Accessing values
print(student["name"])  # Output: saad
print(student["grade"]) # Output: A

# %% [markdown]
#  Alternatively, use  `.get()`  to **avoid errors** if the key does not exist.

# %%
# Using .get() to access values
print(student.get("age"))        # Output: 20
print(student.get("email", "Not found"))  # Output: Not found

# %% [markdown]
# **✅ Practice Exercise:**

# %%
# Create a dictionary for a smartphone with keys like brand, model, and price. Access and print the model.

# %% [markdown]
# <hr>

# %% [markdown]
# ####   Modifying a Dictionary

# %% [markdown]
# Dictionaries are mutable, meaning we can change their values.

# %%
student = {
    "name": "saad",
    "age": 20,
    "grade": "A",
    "city": "Islamabad"
}
print("Origional dictionery: ",student )

# Updating values
student["age"] = 21
print("Updating Age: ", student)  # Updated age to 21


# Adding a new key-value pair
student["email"] = "saad@example.com"
print("Adding Email : ", student)


# Removing a specific key using pop()
student.pop("grade")
print("Removing grade key : ", student)  # "grade" key is removed


# Using del keyword
del student["city"]
print("del city key  : ", student)  # "city" key is removed

# Using clear() to remove all elements
student.clear()
print("Clear All: ", student)  # Output: {}

# %% [markdown]
# <hr>

# %% [markdown]
# <br><br>

# %% [markdown]
# ####   Looping Through a Dictionary

# %% [markdown]
# We can iterate through a dictionary using a `for` loop.

# %%
student = {"name": "saad", "age": 20, "grade": "A"}

# Loop through keys
for key in student:
    print("Keys: ", key)

# Loop through values
for value in student.values():
    print("Value: ",value)

# %%
# Loop through key-value pairs
for key, value in student.items():
    print(f"{key}: {value}")

# %% [markdown]
# **✅ Practice Exercise:**

# %%
# Create a dictionary for a car (brand, model, year) and print each key and value using a loop.

# %% [markdown]
# <hr>

# %% [markdown]
# <br><br>

# %% [markdown]
# ####   Dictionary Methods

# %% [markdown]
# Dictionaries have several useful methods:

# %%
student = {"name": "saad", "age": 20, "grade": "A"}

# Checking if a key exists
print("name" in student)  # Output: True


# Getting all keys
print(student.keys())  # Output: dict_keys(['name', 'age', 'grade'])

# Getting all values
print(student.values())  # Output: dict_values(['saad', 20, 'A'])



# Getting all key-value pairs
print(student.items())  # Output: dict_items([('name', 'saad'), ('age', 20), ('grade', 'A')])

# %% [markdown]
# **✅ Practice Exercise:**

# %%
# Use .keys() and .values() on your car dictionary to print all keys and values separately.

# %% [markdown]
# <hr>

# %% [markdown]
# <br><br>

# %% [markdown]
# ####   Nested Dictionaries

# %% [markdown]
# Dictionaries can store *other dictionaries* inside them.

# %%
students = {
    "saad": {"age": 20, "grade": "A"},
    "Sara": {"age": 22, "grade": "B"}
}
print(students["saad"]["grade"])  # Output: A

# %% [markdown]
# **✅ Practice Exercise:**

# %%
# Create a nested dictionary for two countries with their capital and population.

# %% [markdown]
# ## 📝 Summary / Key Takeaways
# - A **dictionary** stores data as key–value pairs.
# - Keys must be **unique** and **immutable**.
# - Access values using `dict[key]` or `dict.get(key)`.
# - Useful methods: `keys()`, `values()`, `items()`, `update()`, `pop()`.
# - Dictionaries are ideal when you need **fast lookups** by key.
