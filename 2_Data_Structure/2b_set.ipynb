# %% [markdown]
# ## 🚀 **Python Sets: A Beginner's Guide to Unordered Collections** 🧩

# %% [markdown]
# <Hr>

# %% [markdown]
# ## 1️⃣ Introduction to Sets

# %% [markdown]
# ##### What is a Set?

# %% [markdown]
# A **set** in Python is an unordered collection of **unique elements**. It is useful when you need to store **distinct values** and perform mathematical operations like **union, intersection, and difference**

# %% [markdown]
# ##### Creating a Set

# %%
# Creating a set of unique fruits
fruits = {"apple", "banana", "cherry", "apple"}  # Duplicate "apple" is removed
print(fruits)  # Output: {'banana', 'cherry', 'apple'}
# Out:
# {'cherry', 'apple', 'banana'}

# %% [markdown]
# #### 📌 Key Points:
#
# - ✅ **Sets do not allow duplicate values.**
# - 🔄 **Unordered** → No **indexing or position-based access**.
# - 🔧 **Mutable**, but elements must be **immutable** (e.g., numbers, strings, tuples).

# %% [markdown]
# #### ✅ Practice Exercise:

# %%
# Create a set of your favorite colors and print it.

# %% [markdown]
# <hr>

# %% [markdown]
# <br><br>

# %% [markdown]
# ### 2️⃣ Accessing Set Elements

# %% [markdown]
# Sets do **not** support **indexing** , but we can loop through elements.

# %%
fruits = {"apple", "banana", "cherry", "apple"}

# Looping through a set
for fruit in fruits:
    print(fruit)
# Out:
# cherry
# apple
# banana

# %% [markdown]
# #### ✅ Practice Exercise:

# %%
# Create a set of countries and print each country using a loop.

# %% [markdown]
# <hr>

# %% [markdown]
# <br><br>

# %% [markdown]
# ### 3️⃣ Modifying a Set

# %% [markdown]
# We can **add** or **remove** elements.

# %%
fruits = {"apple", "banana", "cherry", "apple"}

# Adding elements
fruits.add("orange")
print(fruits)
# Out:
# {'orange', 'cherry', 'apple', 'banana'}

# %% [markdown]
# <hr>

# %%
# Removing elements
fruits.remove("banana")  # Removes "banana", raises an error if not found
print(fruits)
# Out:
# {'orange', 'cherry', 'apple'}

# %% [markdown]
# <hr>

# %%
# Discarding an element (no error if element is missing)
fruits.discard("grape")  # No error
print(fruits)
# Out:
# {'orange', 'cherry', 'apple'}

# %% [markdown]
# <hr>

# %%
# Removing a random element
fruits.pop()
print(fruits)
# Out:
# {'cherry', 'apple'}

# %% [markdown]
# #### ✅ Practice Exercise:

# %%
# Create a set of your hobbies and add/remove an element.

# %% [markdown]
# <hr>

# %% [markdown]
# <br><br>

# %% [markdown]
# ### 4️⃣ Set Operations

# %% [markdown]
# Sets support **mathematical operations** like **union, intersection** , and **difference**.

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

# Union: Combines all elements (removes duplicates)
print(A | B)  # Output: {1, 2, 3, 4, 5, 6}
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# <hr>

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

# Intersection: Common elements
print(A & B)  # Output: {3, 4}
# Out:
# {3, 4}

# %% [markdown]
# <hr>

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

# Difference: Elements in A but not in B
print(A - B)  # Output: {1, 2}
# Out:
# {1, 2}

# %% [markdown]
# <hr>

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

# Symmetric Difference: Elements in either A or B but not both
print(A ^ B)  # Output: {1, 2, 5, 6}
# Out:
# {1, 2, 5, 6}

# %% [markdown]
# #### ✅ Practice Exercise:

# %% [markdown]
# 📌 **Task:**
# Create **two sets** of students (e.g., `"Math Club"` and `"Science Club"`).
#
# 🔍 **Find the following:**
# - 🏆 Students **in both clubs**.
# - 🎯 Students **only in Math Club**.
# - 🔄 Students **only in one of the clubs**.
#
# ✍️ **Write code to solve this and print the results!**

# %%
# write your code here....

# %% [markdown]
# <hr>

# %% [markdown]
# <br><br>

# %% [markdown]
# ### 5️⃣ Set Methods

# %% [markdown]
# Common set methods:

# %%
A = {1, 2, 3, 4}

# Checking membership
print(2 in A)  # Output: True
# Out:
# True

# %% [markdown]
# <hr>

# %%
A = {1, 2, 3, 4}

# Getting the length of a set
print(len(A))  # Output: 4
# Out:
# 4

# %% [markdown]
# <hr>

# %%
A = {1, 2, 3, 4}

# Clearing all elements
A.clear()
print(A)  # Output: set()
# Out:
# set()

# %% [markdown]
# #### ✅ Practice Exercise:

# %%
# Create a set of languages you know. Check if "Python" is in the set.

# %% [markdown]
# <hr>

# %% [markdown]
# <br><br>

# %% [markdown]
# ### 6️⃣ Frozen Sets (Immutable Sets)

# %% [markdown]
# A **frozen set** is a **read-only version** of a set.

# %%
# Creating a frozen set
frozen_A = frozenset(A)
print(frozen_A)
# Out:
# frozenset()

# %%
# Trying to modify it (will raise an error)
frozen_A.add(5)  # ❌ Error

# %% [markdown]
# #### ✅ Practice Exercise:

# %%
# Try creating a frozen set and attempt to modify it.
